# %% [markdown]
# # GPU SHA-256 — Benchmark on Colab
#
# Builds the project and runs the benchmark pipeline on a Colab GPU.
#
# **Before running:** **Runtime → Change runtime type → T4 GPU → Save**, then reconnect.

# %%
# Step 1 — GPU + CUDA check
# !nvidia-smi
# !nvcc --version

# %%
# Step 2 — Clone repo and install OpenSSL dev headers
BRANCH = "feat/m5-benchmark-makefile"  # use "main" after your PR is merged
REPO = "https://github.com/ananpal/gpu_assignment.git"

# !apt-get install -y -qq libssl-dev
# !rm -rf gpu_assignment
# !git clone -b {BRANCH} {REPO}
# %cd gpu_assignment

# %%
# Step 3 — Build everything
# !make status
# !make all

# %%
# Step 4 — Correctness gate (must print ALL PASS)
# !./build/smoke_test

# %%
# Step 5 — Full pipeline on a small dataset, then benchmark
N = 10_000  # increase to 100_000 or 1_000_000 after this passes

# !make run N={N}
# !./build/benchmark data --block-size 256
